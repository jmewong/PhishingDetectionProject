# %%
using StreamStats
include("./phishing_detection.jl")
# Out:
# INFO: Package DecisionTree is already installed
# INFO: METADATA is out-of-date — you may not have the latest version of DecisionTree
# INFO: Use `Pkg.update()` to get the latest versions of your packages
# Best parameters: Dict{Symbol,Any}(Pair{Symbol,Any}(:C, 0.2))
# WARNING: redefining constant StandardScaler
# WARNING: redefining constant KNeighborsClassifier
# WARNING: redefining constant SVC
# WARNING: redefining constant GaussianNB
# WARNING: redefining constant LinearDiscriminantAnalysis
# WARNING: redefining constant QuadraticDiscriminantAnalysis
# WARNING: redefining constant LogisticRegression
# Best parameters: Dict{Symbol,Any}(Pair{Symbol,Any}(:C, 0.4))
# 0.03113879003558719
# 0.04359430604982206
# 0.029359430604982206
# 0.04359430604982206
#   1.112322 seconds (5.11 k allocations: 19.349 MiB, 1.07% gc time)
#   0.495191 seconds (4.93 k allocations: 19.345 MiB, 1.58% gc time)
# WARNING: max{T1 <: Real}(x::AbstractArray{T1}, y::Real) is deprecated, use max.(x, y) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] max(::Array{Float64,1}, ::Int64) at ./deprecated.jl:57
#  [3] #proxgrad#13(::Int64, ::Float64, ::LowRankModels.ConvergenceHistory, ::Function, ::LowRankModels.LogisticLoss, ::LowRankModels.OneReg, ::Array{Float64,2}, ::Array{Bool,1}) at /Users/Joshua/Documents/orie4741/ORIE4741-FP/phishing_detection.jl:213
#  [4] (::#kw##proxgrad)(::Array{Any,1}, ::#proxgrad, ::LowRankModels.LogisticLoss, ::LowRankModels.OneReg, ::Array{Float64,2}, ::Array{Bool,1}) at ./<missing>:0
#  [5] include_from_node1(::String) at ./loading.jl:569
#  [6] include(::String) at ./sysimg.jl:14
#  [7] include_string(::String, ::String) at ./loading.jl:515
#  [8] include_string(::Module, ::String, ::String) at /Users/Joshua/.julia/v0.6/Compat/src/Compat.jl:478
#  [9] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/Joshua/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [10] eventloop(::ZMQ.Socket) at /Users/Joshua/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [11] (::IJulia.##14#17)() at ./task.jl:335
# while loading /Users/Joshua/Documents/orie4741/ORIE4741-FP/phishing_detection.jl, in expression starting on line 232
# WARNING: sumabs(x) is deprecated, use sum(abs, x) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] sumabs(::Array{Float64,1}) at ./deprecated.jl:57
#  [3] evaluate at /Users/Joshua/.julia/v0.6/LowRankModels/src/regularizers.jl:87 [inlined]
#  [4] #proxgrad#13(::Int64, ::Float64, ::LowRankModels.ConvergenceHistory, ::Function, ::LowRankModels.LogisticLoss, ::LowRankModels.OneReg, ::Array{Float64,2}, ::Array{Bool,1}) at /Users/Joshua/Documents/orie4741/ORIE4741-FP/phishing_detection.jl:215
#  [5] (::#kw##proxgrad)(::Array{Any,1}, ::#proxgrad, ::LowRankModels.LogisticLoss, ::LowRankModels.OneReg, ::Array{Float64,2}, ::Array{Bool,1}) at ./<missing>:0
#  [6] include_from_node1(::String) at ./loading.jl:569
#  [7] include(::String) at ./sysimg.jl:14
#  [8] include_string(::String, ::String) at ./loading.jl:515
#  [9] include_string(::Module, ::String, ::String) at /Users/Joshua/.julia/v0.6/Compat/src/Compat.jl:478
#  [10] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/Joshua/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [11] eventloop(::ZMQ.Socket) at /Users/Joshua/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [12] (::IJulia.##14#17)() at ./task.jl:335
# while loading /Users/Joshua/Documents/orie4741/ORIE4741-FP/phishing_detection.jl, in expression starting on line 232
# [8.4698e-6, -1.26096e-5, 9.09368e-6, -1.67756e-6, 3.90344e-6, 0.000145087, 6.49581e-5, 0.000201208, 5.76856e-5, -2.80044e-6, -7.65739e-6, 6.50795e-6, -9.11803e-6, 0.000199493, 3.33093e-5, -1.44379e-5, -5.2181e-7, 8.51096e-6, -2.44686e-6, -9.41284e-6, -2.04038e-7, -3.38867e-6, 1.38933e-6, 6.63553e-5, -0.000130934, 0.000155586, 9.76267e-5, 2.5204e-5, -4.14864e-6, -2.73284e-6, -0.000110084]
# 0.00020120822742217016
# 0.550711743772242
# WARNING: imported binding for names overwritten in module Main
# 0.9403914590747331
# 0.9341637010676157
# 0.7277580071174378
# 0.9412811387900356
# 0.9519572953736655
# 0.9110320284697508
# 0.9261565836298933
# 0.9359430604982206
# 0.9234875444839857
# Feature 8, Threshold 0
# L-> Feature 14, Threshold 1
#     L-> Feature 6, Threshold 1
#         L-> -1 : 986/986
#         R-> Feature 30, Threshold 1
#             L-> Feature 10, Threshold 1
#                 L-> -1 : 43/43
#                 R->
#             R-> -1 : 443/444
#     R-> Feature 7, Threshold 0
#         L-> Feature 15, Threshold 1
#             L-> Feature 26, Threshold 1
#                 L-> -1 : 57/58
#                 R->
#             R-> -1 : 39/39
#         R-> Feature 6, Threshold 1
#             L-> Feature 27, Threshold 1
#                 L->
#                 R-> -1 : 26/26
#             R-> Feature 24, Threshold 1
#                 L->
#                 R->
# R-> Feature 14, Threshold 0
#     L-> Feature 6, Threshold 1
#         L-> Feature 25, Threshold 1835
#             L-> Feature 13, Threshold 0
#                 L->
#                 R->
#             R-> -1 : 49/49
#         R-> Feature 26, Threshold 1
#             L-> Feature 7, Threshold 0
#                 L-> -1 : 38/38
#                 R->
#             R-> Feature 24, Threshold 1
#                 L->
#                 R->
#     R-> Feature 27, Threshold 1
#         L-> Feature 24, Threshold 1
#             L-> Feature 7, Threshold 1
#                 L->
#                 R-> 1 : 34/34
#             R-> Feature 26, Threshold 1
#                 L->
#                 R->
#         R-> Feature 7, Threshold 0
#             L-> Feature 6, Threshold 1
#                 L-> -1 : 18/20
#                 R->
#             R-> Feature 8, Threshold 1
#                 L->
#                 R->
# false positive: 0.02402135231316726
# false negative: 0.03469750889679715
# total error 0.05871886120996441
#
# Fold 1
# Classes:
# 2×2 Array{Int64,2}:
#  726   32
#   38  537
# [-1, 1]
# Matrix:
# Accuracy: 0.9474868717179294
# Kappa:    0.8928212891769143
# 2×2 Array{Int64,2}:
#  687   47
#   33  566
# Fold 2
# Classes:  [-1, 1]
# Matrix:
# Accuracy: 0.9399849962490623
# Kappa:    0.878986225945335
# 2×2 Array{Int64,2}:
#  697   38
#   30  568
# Fold 3
# Classes:  [-1, 1]
# Matrix:
# Accuracy: 0.9489872468117029
# Kappa:    0.8970137112057407
#
# Mean Accuracy: 0.9454863715928982
# false positive: 0.02491103202846975
# false negative: 0.023131672597864767
# total error 0.04804270462633452

# %%
using PyPlot

# %%
dataset;

# %%
function produce_proportions(col_number, y_vector, dataset)
    l = length(y_vector)
    #number of classified "phishing" for each category
    count_negative_one = 0
    count_zero = 0
    count_positive_one = 0
    for i=1:l
        if y_vector[i] == 1
            if dataset[i,col_number] == -1
                count_negative_one += 1
            end

            if dataset[i,col_number] == 0
                count_zero += 1
            end

            if dataset[i,col_number] == 1
                count_positive_one += 1
            end
        end
    end
    
    a = count_negative_one / l, count_zero / l, count_positive_one / l
    return [x for x in a]
end

function prop_compare(col_number, y_vector, dataset)
    x = produce_proportions(col_number, y_vector, dataset)
    y = produce_proportions(col_number, dataset[:,:Result], dataset)
    
    return [x y]
end
prop = prop_compare(1, ylog, dataset)

#plot colorcoded heatmap of binary values (% classified as phishing or legitimate)
#compare to the true heatmap
#do it for each feature
#do it for each model
size(dataset)
# Out:
# (5124, 32)

# %%
for i in 1:size(dataset)[2]
    PyPlot.figure()
    fig = imshow(prop_compare(i, ylog, dataset), cmap="hot", interpolation="bilinear", 
        origin="upper", extent=(0,1,-1,1))
    suptitle("Logistic Regression: " * String(DataFrames.names(dataset)[i]))
    locs, _ = xticks()
    xticks([.2,.8], ["true", "predicted"])
    locs, _ = yticks()
    yticks(locs, ["-1", "","","","0","","","", "1"])
    fig
end
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a810f88d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a7f159fd0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a7ee57990>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a7ed56d10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a7c1f8390>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x12bc22ad0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a818dd550>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a8198d550>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a81a29350>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a81abce10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a81b43850>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a81bdd5d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a81caba10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a81d53250>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a81e05d50>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a81eb4910>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a81f5a050>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a81efcb10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a82089690>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a8211b710>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a821029d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a82260390>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a8233a210>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a823d5710>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a8247cf90>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a82425f90>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a825b1150>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a826443d0>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a8262df10>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a82788710>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a82862350>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a828feb10>)
# /Users/Joshua/.julia/v0.6/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
fig = imshow(prop_compare(2, ylog, dataset), cmap="hot", interpolation="bilinear", 
    origin="upper", extent=(0,1,-1,1))
colorbar()
suptitle("Logistic Regression:")
locs, _ = xticks()
xticks([.2,.8], ["true", "predicted"])
locs, _ = yticks()
yticks(locs, ["-1", "","","","0","","","", "1"])
# Out:
# PyError (ccall(@pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, arg, kw)) <type 'exceptions.TypeError'>
# TypeError(u'Invalid dimensions for image data',)
#   File "/Users/Joshua/.julia/v0.6/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/pyplot.py", line 3157, in imshow
#     **kwargs)
#   File "/Users/Joshua/.julia/v0.6/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/__init__.py", line 1898, in inner
#     return func(ax, *args, **kwargs)
#   File "/Users/Joshua/.julia/v0.6/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/axes/_axes.py", line 5124, in imshow
#     im.set_data(X)
#   File "/Users/Joshua/.julia/v0.6/Conda/deps/usr/lib/python2.7/site-packages/matplotlib/image.py", line 600, in set_data
#     raise TypeError("Invalid dimensions for image data")
#
#
# Stacktrace:
#  [1] pyerr_check at /Users/Joshua/.julia/v0.6/PyCall/src/exception.jl:56 [inlined]
#  [2] pyerr_check at /Users/Joshua/.julia/v0.6/PyCall/src/exception.jl:61 [inlined]
#  [3] macro expansion at /Users/Joshua/.julia/v0.6/PyCall/src/exception.jl:81 [inlined]
#  [4] #_pycall#67(::Array{Any,1}, ::Function, ::PyCall.PyObject, ::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at /Users/Joshua/.julia/v0.6/PyCall/src/PyCall.jl:658
#  [5] (::PyCall.#kw##_pycall)(::Array{Any,1}, ::PyCall.#_pycall, ::PyCall.PyObject, ::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at ./<missing>:0
#  [6] #pycall#71(::Array{Any,1}, ::Function, ::PyCall.PyObject, ::Type{PyCall.PyAny}, ::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at /Users/Joshua/.julia/v0.6/PyCall/src/PyCall.jl:675
#  [7] (::PyCall.#kw##pycall)(::Array{Any,1}, ::PyCall.#pycall, ::PyCall.PyObject, ::Type{PyCall.PyAny}, ::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at ./<missing>:0
#  [8] #imshow#67(::Array{Any,1}, ::Function, ::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at /Users/Joshua/.julia/v0.6/PyPlot/src/PyPlot.jl:172
#  [9] (::PyPlot.#kw##imshow)(::Array{Any,1}, ::PyPlot.#imshow, ::Array{Float64,1}, ::Vararg{Array{Float64,1},N} where N) at ./<missing>:0
#  [10] include_string(::String, ::String) at ./loading.jl:515

# %%
imshow(produce_proportions(1, y_i2, dataset), cmap="hot", interpolation="bilinear", 
    origin="lower")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a78fe7050>)
# PyObject <matplotlib.image.AxesImage object at 0x1a7942c0d0>

# %%
imshow([[.4,0,.6],[.3,0,.7]], cmap="hot", interpolation="bilinear", 
    origin="lower", extent=(0,1,-1,1), vmin=0, vmax=1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x1a76dfe750>)
# PyObject <matplotlib.image.AxesImage object at 0x1a76f8a310>

# %%
# Out:
# 2-element Array{Array{Float64,1},1}:
#  [-1.0, 0.0, 1.0]
#  [0.4, 0.0, 0.6]
